# %% [markdown]
# ## Intstallation libraries

# %%
# !apt-get install xvfb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,271 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.10 [784 kB]
# Fetched 784 kB in 0s (3,100 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
pip install xvfbwrapper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for xvfbwrapper: filename=xvfbwrapper-0.2.9-py3-none-any.whl size=5023 sha256=b65316af1b8d424075a23a4dfd936f14b78cfdb35575d44d158204741bdf7423
#   Stored in directory: /root/.cache/pip/wheels/f4/a7/4b/c559bd2437620de067a11d4ab79222445bfe3c4f2130882f76
# Successfully built xvfbwrapper
# ...

# %%
# %%bash
#
# # install required system dependencies
# apt-get install -y xvfb x11-utils
#
# # install required python dependencies (might need to install additional gym extras depending)
# pip install gym[box2d]==0.17.* pyvirtualdisplay==0.2.* PyOpenGL==3.1.* PyOpenGL-accelerate==3.1.*
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# xvfb is already the newest version (2:1.19.6-1ubuntu4.10).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libxxf86dga1 x11-utils
# 0 upgraded, 2 newly installed, 0 to remove and 45 not upgraded.
# Need to get 209 kB of archives.
# After this operation, 711 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Fetched 209 kB in 1s (365 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 155639 files and directories currently installed.)
# ...

# %%
pip install pygame
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 21.8 MB 1.5 MB/s
# ...

# %%
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=False, size=(1400, 900))
virtual_display.start()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 496 kB of archives.
# After this operation, 5,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Fetched 496 kB in 0s (2,260 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 155693 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Reading package lists... Done
# Building dependency tree
# ...

# %% [markdown]
# ## import libraries and import Environment of gym

# %%
import gym
from gym import wrappers
from IPython import display
from xvfbwrapper import Xvfb
import numpy as np
import time
import pyglet
import gym
import PIL.Image
import io

# %%
import matplotlib.pyplot as plt
import gc
import random
import time

from collections import deque
from IPython.display import clear_output

# %%
# %matplotlib inline

import gym
import itertools
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import sys
import sklearn.pipeline
import sklearn.preprocessing

if "../" not in sys.path:
  sys.path.append("../") 

from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler

matplotlib.style.use('ggplot')

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# %matplotlib inline

import gym
import itertools
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

import sys
import sklearn.pipeline
import sklearn.preprocessing

if "../" not in sys.path:
  sys.path.append("../") 


from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler

matplotlib.style.use('ggplot')

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # imort libraries and define  plotting function

# %%
import matplotlib
import numpy as np
import pandas as pd
from collections import namedtuple
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

EpisodeStats = namedtuple("Stats",["episode_lengths", "episode_rewards"])

def plot_episode_stats(stats, smoothing_window=10, noshow=False):
    # Plot the episode length over time
    fig1 = plt.figure(figsize=(10,5))
    plt.plot(stats.episode_lengths)
    plt.xlabel("Episode")
    plt.ylabel("Episode Length")
    plt.title("Episode Length over Time")
    amax = np.argmin(stats.episode_lengths)
    xlim,ylim = plt.xlim(), plt.ylim()
    plt.plot([ np.arange(1, len(stats.episode_lengths) + 1, 1)[amax],  np.arange(1, len(stats.episode_lengths) + 1, 1)[amax], xlim[0]], [xlim[0],stats.episode_lengths[amax], stats.episode_lengths[amax]],
        linestyle="--")
    plt.xlim(xlim)
    plt.ylim(ylim)
    if noshow:
        plt.close(fig1)
    else:
        plt.show(fig1)

    # Plot the episode reward over time
    fig2 = plt.figure(figsize=(10,5))
    #rewards_smoothed = pd.Series(stats.episode_rewards).rolling(smoothing_window, min_periods=smoothing_window).mean()
    plt.plot(stats.episode_rewards)
    plt.xlabel("Episode")
    plt.ylabel("episode_rewards")
    plt.title("Episode Reward over Time (Smoothed over window size {})".format(smoothing_window))
    amax = np.argmax(stats.episode_rewards)
    xlim,ylim = plt.xlim(), plt.ylim()
    plt.plot([ np.arange(1, len(stats.episode_rewards) + 1, 1)[amax],  np.arange(1, len(stats.episode_rewards) + 1, 1)[amax], xlim[0]], [xlim[0],stats.episode_rewards[amax], stats.episode_rewards[amax]],
        linestyle="--")
    plt.xlim(xlim)
    plt.ylim(ylim)
    if noshow:
        plt.close(fig2)
    else:
        plt.show(fig2)

# Plot time steps and episode number
    fig3 = plt.figure(figsize=(10,5))
    plt.plot(np.cumsum(stats.episode_lengths), np.arange(len(stats.episode_lengths)))
    plt.xlabel("Time Steps")
    plt.ylabel("Episode")
    plt.title("Episode per time step")
    if noshow:
        plt.close(fig3)
    else:
        plt.show(fig3)

    return fig1, fig2, fig3

# %% [markdown]
#  ## Implementaion to environment

# %%
import numpy as np
import copy
import matplotlib.pyplot as mplt_pyplt
import matplotlib.pyplot as plt

# %%
env = gym.envs.make("MountainCar-v0")

# %%
observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(observation_examples)
# Out:
# StandardScaler()

# %%
from sklearn.pipeline import FeatureUnion

# %%
observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
scaler = sklearn.preprocessing.StandardScaler()


featurizer = sklearn.pipeline.FeatureUnion([
        ("rbf1", RBFSampler(gamma=5.0, n_components=100)),
        ("rbf2", RBFSampler(gamma=2.0, n_components=100)),
        ("rbf3", RBFSampler(gamma=1.0, n_components=100)),
        ("rbf4", RBFSampler(gamma=0.5, n_components=100))
        ])

# %%
featurizer.fit_transform(scaler.fit_transform(observation_examples))
# Out:
# array([[ 0.13382636,  0.10400313,  0.14130797, ...,  0.05316797,
#         -0.13663307, -0.09475621],
#        [ 0.0790995 ,  0.09638946, -0.14092832, ..., -0.13287777,
#         -0.08070446,  0.00373049],
#        [ 0.13521158, -0.12614696, -0.13300044, ...,  0.14079248,
#         -0.12036942,  0.09157515],
#        ...,
#        [-0.13736709, -0.11860051, -0.00361538, ..., -0.01927281,
#         -0.08643201, -0.08837984],
#        [ 0.04033633,  0.13925951, -0.13629614, ..., -0.11267827,
#         -0.08649938, -0.01453449],
#        [-0.0087468 ,  0.14131457,  0.00593937, ..., -0.13411879,
#         -0.13067032,  0.12196878]])

# %%
import gym
from keras import models
from keras import layers
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
import numpy as np


#############################
#if you want to use GPU to boost, use these code.  

import tensorflow as tf
import keras
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

#############################


class MountainCarTrain:
    def __init__(self,env):
        self.env=env
        self.gamma=0.99

        self.epsilon = 1
        self.epsilon_decay = 0.05

        self.epsilon_min=0.01
        self.__time_steps = 0
        self.__records = []
        self.__records1 = []
        self.learingRate=0.001

        self.replayBuffer=deque(maxlen=20000)
        self.trainNetwork=self.createNetwork()

        self.__episodeNum=0

        self.iterationNum=201 #max is 200


    def __initialize(self, episodeNum):
        self.__episodeNum=episodeNum
    def createNetwork(self):
        self.models = []
        for i in range(env.action_space.n):
            model = SGDRegressor(learning_rate="constant")
            model.partial_fit([self.featurize_state(env.reset())], [0])
            self.models.append(model)
    def predict(self, s, a=None):
        
        state_features = self.featurize_state(s)
        if not a:
            return np.array([m.predict([state_features])[0] for m in self.models])
        else:
            return self.models[a].predict([state_features])[0]
        
    def update(self, s, a, y):
       
        features = self.featurize_state(s)
        
        self.models[a].partial_fit([features], [y])  
    def featurize_state(self, state):
        
        scaled = scaler.transform([state])
        features = featurizer.transform(scaled)
        return features[0]
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Case 1
# ## Applying Question 3  with Question 1to determine  maximum and minimum return.

# %% [markdown]
# ## Question 1 with question 3
# ##Train function

# %% [markdown]
# ## queue learning approximation algoritm

# %%
def make_epsilon_greedy_policy(estimator, epsilon, nA):
    
    def policy_fn(observation):
        A = np.ones(nA, dtype=float) * epsilon / nA
        q_values = estimator.predict(observation)
        best_action = np.argmax(q_values)
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
def q_learning(env, estimator, num_episodes, discount_factor=1.0, epsilon=0.1, epsilon_decay=1.0):
    """
    Q-Learning algorithm for fff-policy TD control using Function Approximation.
    Finds the optimal greedy policy while following an epsilon-greedy policy.
    
    Args:
        env: OpenAI environment.
        estimator: Action-Value function estimator
        num_episodes: Number of episodes to run for.
        discount_factor: Lambda time discount factor.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.
        epsilon_decay: Each episode, epsilon is decayed by this factor
    
    Returns:
        An EpisodeStats object with two numpy arrays for episode_lengths and episode_rewards.
    """
    # Keeps track of useful statistics
    stats = EpisodeStats(
        episode_lengths=np.zeros(num_episodes),
        episode_rewards=np.zeros(num_episodes))    
    
    for i_episode in range(num_episodes):
        
        # The policy we're following
        policy = make_epsilon_greedy_policy(
            estimator, epsilon * epsilon_decay**i_episode, env.action_space.n)
        
        # Print out which episode we're on, useful for debugging.
        # Also print reward for last episode
        last_reward = stats.episode_rewards[i_episode - 1]
        sys.stdout.flush()
        
        # Reset the environment and pick the first action
        state = env.reset()
        
        # Only used for SARSA, not Q-Learning
        next_action = None
        
        # One step in the environment
        for t in itertools.count():
                        
            # Choose an action to take
            # If we're using SARSA we already decided in the previous step
            if next_action is None:
                action_probs = policy(state)
                action = np.random.choice(np.arange(len(action_probs)), p=action_probs)
            else:
                action = next_action
            
            # Take a step
            next_state, reward, done, _ = env.step(action)
    
            # Update statistics
            stats.episode_rewards[i_episode] += reward
            stats.episode_lengths[i_episode] = t
            
            # TD Update
            q_values_next = estimator.predict(next_state)
            
            # Use this code for Q-Learning
            # Q-Value TD Target
            td_target = reward + discount_factor * np.max(q_values_next)
            
            # Use this code for SARSA TD Target for on policy-training:
            # next_action_probs = policy(next_state)
            # next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)             
            # td_target = reward + discount_factor * q_values_next[next_action]
            
            # Update the function approximator using our target
            estimator.update(state, action, td_target)
            
            print("\rStep {} @ Episode {}/{} ({})".format(t, i_episode + 1, num_episodes, last_reward), end="")    
            if done:
                t+=1
                break
                
            state = next_state
    
    return stats

# %%
estimator = MountainCarTrain(env)

# %% [markdown]
# # test function for QUestion 1

# %%
def test(num_episodes,estimator):
  episode_lengths=[]
  episode_rewards=[]
  rewards=0
  env = gym.make('MountainCar-v0')
  env.reset()
  Reward=[]
  for episode in range(num_episodes):
      state = env.reset()
      rewards = 0
      for t in range(200):
          q_values = estimator.predict(state)
          best_action = np.argmax(q_values)
          new_state, reward, done, info = env.step( best_action)
          new_state = new_state
          state=new_state
          rewards += reward
          if done:
              t+=1
              episode_lengths.append(t)
              episode_rewards.append(rewards)
              print("\rStep Step of test {} @ Episode {}/{} ({})".format(t, episode + 1, num_episodes , rewards))  
              break
  return episode_rewards , episode_lengths

# %% [markdown]
# ##Question 2
#
# ##with question 3.

# %%
def q_learning1(env, estimator, num_episodes, discount_factor=1.0, epsilon=0.1, epsilon_decay=1.0):
    """
    Q-Learning algorithm for fff-policy TD control using Function Approximation.
    Finds the optimal greedy policy while following an epsilon-greedy policy.
    
    Args:
        env: OpenAI environment.
        estimator: Action-Value function estimator
        num_episodes: Number of episodes to run for.
        discount_factor: Lambda time discount factor.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.
        epsilon_decay: Each episode, epsilon is decayed by this factor
    
    Returns:
        An EpisodeStats object with two numpy arrays for episode_lengths and episode_rewards.
    """
    # Keeps track of useful statistics
 # Keeps track of useful statistics
    stats = EpisodeStats(
        episode_lengths=np.zeros(num_episodes),
        episode_rewards=np.zeros(num_episodes))  
    eps_length_test=[]
    reward_test=[]
    mean_r_test=[]
    mean_l_test=[]
    for i_episode in range(num_episodes):
        # The policy we're following
          policy = make_epsilon_greedy_policy(
              estimator, epsilon * epsilon_decay**i_episode, env.action_space.n)
          
          # Print out which episode we're on, useful for debugging.
          # Also print reward for last episode
          last_reward = stats.episode_rewards[i_episode - 1]
          sys.stdout.flush()
          
          # Reset the environment and pick the first action
          state = env.reset()
          
          # Only used for SARSA, not Q-Learning
          next_action = None
          
          # One step in the environment
          for t in itertools.count():
                          
              # Choose an action to take
              # If we're using SARSA we already decided in the previous step
              if next_action is None:
                  action_probs = policy(state)
                  action = np.random.choice(np.arange(len(action_probs)), p=action_probs)
              else:
                  action = next_action
              
              # Take a step
              next_state, reward, done, _ = env.step(action)
      
              # Update statistics
              stats.episode_rewards[i_episode] += reward
              stats.episode_lengths[i_episode] = t
              
              # TD Update
              q_values_next = estimator.predict(next_state)
              
              # Use this code for Q-Learning
              # Q-Value TD Target
              td_target = reward + discount_factor * np.max(q_values_next)
              
              # Use this code for SARSA TD Target for on policy-training:
              # next_action_probs = policy(next_state)
              # next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)             
              # td_target = reward + discount_factor * q_values_next[next_action]
              
              # Update the function approximator using our target
              estimator.update(state, action, td_target) 
              if done:
                  t+=1
                  print("\rStep {} @ Episode {}/{} ({})".format(t, i_episode + 1, num_episodes, last_reward))
                  if (i_episode+1)%10 ==0 : 
                    for x in range(1):
                       episode_reward,episode_length=test(5,estimator)
             #          reward_test.append(episode_reward)
             #          eps_length_test.append(episode_length)
                       mean_re_test=np.mean(episode_reward)
                       mean_le_test=np.mean(episode_length)
                       mean_r_test.append(mean_re_test)
                       mean_l_test.append(mean_le_test)
                  break 
              state = next_state
      
    return stats,mean_l_test,mean_r_test

# %%
mean_r_train,mean_l_test,mean_r_test= q_learning1(env, estimator, 400, epsilon=0.0)
# Out:
# Step 200 @ Episode 1/400 (0.0)
# Step 200 @ Episode 2/400 (-200.0)
# Step 200 @ Episode 3/400 (-200.0)
# Step 200 @ Episode 4/400 (-200.0)
# Step 200 @ Episode 5/400 (-200.0)
# Step 200 @ Episode 6/400 (-200.0)
# Step 200 @ Episode 7/400 (-200.0)
# Step 200 @ Episode 8/400 (-200.0)
# Step 200 @ Episode 9/400 (-200.0)
# Step 200 @ Episode 10/400 (-200.0)
# Step Step of test 200 @ Episode 1/5 (-200.0)
# Step Step of test 200 @ Episode 2/5 (-200.0)
# Step Step of test 200 @ Episode 3/5 (-200.0)
# Step Step of test 200 @ Episode 4/5 (-200.0)
# Step Step of test 200 @ Episode 5/5 (-200.0)
# Step 200 @ Episode 11/400 (-200.0)
# Step 200 @ Episode 12/400 (-200.0)
# Step 200 @ Episode 13/400 (-200.0)
# Step 200 @ Episode 14/400 (-200.0)
# Step 200 @ Episode 15/400 (-200.0)
# Step 200 @ Episode 16/400 (-200.0)
# Step 200 @ Episode 17/400 (-200.0)
# Step 200 @ Episode 18/400 (-200.0)
# Step 200 @ Episode 19/400 (-200.0)
# Step 200 @ Episode 20/400 (-200.0)
# ...

# %%
plt.figure(figsize = (19, 10))

# Episode reward plot
fig1 = plt.figure(figsize=(10,5))
plt.plot(mean_l_test)
plt.xlabel("Episode")
plt.ylabel("MEAN Episode Length(test)")
plt.title("MEAN Episode Length over Time(test)")
amax = np.argmin(mean_l_test)
xlim,ylim = plt.xlim(), plt.ylim()
plt.plot([ np.arange(1, len(mean_l_test) + 1, 1)[amax],  np.arange(1, len(mean_l_test) + 1, 1)[amax], xlim[0]], [xlim[0],mean_l_test[amax], mean_l_test[amax]],
        linestyle="--")
plt.xlim(xlim)
plt.ylim(ylim)
plt.show(fig1)
# Plot time steps and episode number
fig2=plt.figure(figsize =(10, 5))
plt.plot(mean_r_test)
plt.xlabel("Episode")
plt.ylabel("MEAN Episode Reward")
plt.title("MEAN Episode Reward over Time (test)")
amax = np.argmax(mean_r_test)
xlim,ylim = plt.xlim(), plt.ylim()
plt.plot([ np.arange(1, len(mean_r_test) + 1, 1)[amax],  np.arange(1, len(mean_r_test) + 1, 1)[amax], xlim[0]], [xlim[0],mean_r_test[amax], mean_r_test[amax]],linestyle="--")
plt.xlim(xlim)
plt.ylim(ylim)
plt.show(fig2)
# Plot time steps and episode number
fig3 = plt.figure(figsize=(10,5))
plt.plot(np.cumsum(mean_l_test), np.arange(len(mean_l_test)))
plt.xlabel("Time Steps")
plt.ylabel("Episode")
plt.title("Episode per time step")
# Out:
# Text(0.5, 1.0, 'Episode per time step')

# %%
plot_episode_stats(mean_r_train, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# ##test function to Question 2 with updates in  Question
# ## Applying Question 3  with Question 2 to determine  maximum and minimum return.

# %%
import gym
from gym import wrappers
from IPython import display
from xvfbwrapper import Xvfb
import numpy as np
import time
import pyglet
import gym
import PIL.Image
import io    
def test1(num_episodes,estimator):

  env = gym.make('MountainCar-v0')
  env.reset()
  #model=models.load_model('/content/trainNetworkInEPS90.h5')
  t_step=[]
  Rewards=[]
  step = 0
  stats2 = EpisodeStats(
          episode_lengths=np.zeros(num_episodes),
          episode_rewards=np.zeros(num_episodes))   
  for episode in range(num_episodes):
      state = env.reset()
      total_reward = 0
      for t in range(200):
          step += 1
          q_values = estimator.predict(state)
          best_action = np.argmax(q_values)
          new_state, reward, done, info = env.step( best_action)
          new_state = new_state
          state=new_state
          stats2.episode_rewards[episode] += reward
          stats2.episode_lengths[episode] = t
          time.sleep(0.01)
          if done:
              t+=1
              print("Episode: {0},\tSteps: {1},\tscore: {2}"
                    .format(episode, t, stats2.episode_rewards[episode])
              )

              break
  return stats2

# %%
import gym
from gym import wrappers
from IPython import display
from xvfbwrapper import Xvfb
import numpy as np
import time
import pyglet
import gym
import PIL.Image
import io    
def test2_display(num_episodes,estimator):
  vdisplay = Xvfb(width=1280, height=740)
  vdisplay.start()

  env = gym.make('MountainCar-v0')
  env.reset()
    #model=models.load_model('/content/trainNetworkInEPS90.h5')
  def showarray(a, fmt='png'):
      a = np.uint8(a)
      f = io.BytesIO()
      im = PIL.Image.fromarray(a).save(f, fmt)
      return f.getvalue()

  imagehandle = display.display(display.Image(data=showarray(env.render(mode='rgb_array')), width=450), display_id='gymscr')
  t_step=[]
  Rewards=[]
  step = 0
  stats3 = EpisodeStats(
          episode_lengths=np.zeros(num_episodes),
          episode_rewards=np.zeros(num_episodes))   
  for episode in range(num_episodes):
      state = env.reset()
      total_reward = 0
      for t in range(200):
          step += 1
          q_values = estimator.predict(state)
          best_action = np.argmax(q_values)
          new_state, reward, done, info = env.step( best_action)
          new_state = new_state
          state=new_state
          stats3.episode_rewards[episode] += reward
          stats3.episode_lengths[episode] = t
          time.sleep(0.01)
          m= display.update_display(display.Image(data=showarray(env.render(mode='rgb_array')), width=450), display_id='gymscr')
          if done:
              t+=1
              print("Episode: {0},\tSteps: {1},\tscore: {2}"
                    .format(episode, step, stats3.episode_rewards[episode])
              )

              break
  
  vdisplay.stop()
  return stats3

# %%
#pip uninstall pyglet

# %%
#pip install pyglet==1.4.11

# %% [markdown]
# ## Question 4
# ##Tuning hyper parameters

# %% [markdown]
# ##when numberof epsiodes =300,discount_factor has different values in each time=[1,.6,.1]

# %% [markdown]
# 1

# %%
stats1_Q1= q_learning(env, estimator, 300,discount_factor=1.0)
# Out:
# Step 159 @ Episode 300/300 (-93.0)

# %%
plot_episode_stats(stats1_Q1, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 135,	score: -135.0
# Episode: 1,	Steps: 106,	score: -106.0
# Episode: 2,	Steps: 137,	score: -137.0
# Episode: 3,	Steps: 121,	score: -121.0
# Episode: 4,	Steps: 116,	score: -116.0
# Episode: 5,	Steps: 84,	score: -84.0
# Episode: 6,	Steps: 137,	score: -137.0
# Episode: 7,	Steps: 137,	score: -137.0
# Episode: 8,	Steps: 150,	score: -150.0
# Episode: 9,	Steps: 137,	score: -137.0
# Episode: 10,	Steps: 136,	score: -136.0
# Episode: 11,	Steps: 150,	score: -150.0
# Episode: 12,	Steps: 147,	score: -147.0
# Episode: 13,	Steps: 123,	score: -123.0
# Episode: 14,	Steps: 137,	score: -137.0
# Episode: 15,	Steps: 106,	score: -106.0
# Episode: 16,	Steps: 137,	score: -137.0
# Episode: 17,	Steps: 144,	score: -144.0
# Episode: 18,	Steps: 144,	score: -144.0
# Episode: 19,	Steps: 126,	score: -126.0

# %%
plot_episode_stats(stats_test, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# ,6

# %%
stats_q2= q_learning(env, estimator, 300,discount_factor=.6)
# Out:
# Step 199 @ Episode 300/300 (-200.0)

# %%
plot_episode_stats(stats_q2, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test1=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 200,	score: -200.0
# Episode: 1,	Steps: 200,	score: -200.0
# Episode: 2,	Steps: 200,	score: -200.0
# Episode: 3,	Steps: 200,	score: -200.0
# Episode: 4,	Steps: 200,	score: -200.0
# Episode: 5,	Steps: 200,	score: -200.0
# Episode: 6,	Steps: 200,	score: -200.0
# Episode: 7,	Steps: 200,	score: -200.0
# Episode: 8,	Steps: 200,	score: -200.0
# Episode: 9,	Steps: 200,	score: -200.0
# Episode: 10,	Steps: 200,	score: -200.0
# Episode: 11,	Steps: 200,	score: -200.0
# Episode: 12,	Steps: 200,	score: -200.0
# Episode: 13,	Steps: 200,	score: -200.0
# Episode: 14,	Steps: 200,	score: -200.0
# Episode: 15,	Steps: 200,	score: -200.0
# Episode: 16,	Steps: 200,	score: -200.0
# Episode: 17,	Steps: 200,	score: -200.0
# Episode: 18,	Steps: 200,	score: -200.0
# Episode: 19,	Steps: 200,	score: -200.0

# %%
plot_episode_stats(stats_test1, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# .1

# %%
stats_Q3= q_learning(env, estimator, 300,discount_factor=.1)
# Out:
# Step 199 @ Episode 300/300 (-200.0)

# %%
plot_episode_stats(stats_Q3, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test3=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 200,	score: -200.0
# Episode: 1,	Steps: 200,	score: -200.0
# Episode: 2,	Steps: 200,	score: -200.0
# Episode: 3,	Steps: 200,	score: -200.0
# Episode: 4,	Steps: 200,	score: -200.0
# Episode: 5,	Steps: 200,	score: -200.0
# Episode: 6,	Steps: 200,	score: -200.0
# Episode: 7,	Steps: 200,	score: -200.0
# Episode: 8,	Steps: 200,	score: -200.0
# Episode: 9,	Steps: 200,	score: -200.0
# Episode: 10,	Steps: 200,	score: -200.0
# Episode: 11,	Steps: 200,	score: -200.0
# Episode: 12,	Steps: 200,	score: -200.0
# Episode: 13,	Steps: 200,	score: -200.0
# Episode: 14,	Steps: 200,	score: -200.0
# Episode: 15,	Steps: 200,	score: -200.0
# Episode: 16,	Steps: 200,	score: -200.0
# Episode: 17,	Steps: 200,	score: -200.0
# Episode: 18,	Steps: 200,	score: -200.0
# Episode: 19,	Steps: 200,	score: -200.0

# %%
plot_episode_stats(stats_test3, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# ##when discount_factor =1, numberof epsiodes have different values in each time=[200,400,100]

# %% [markdown]
# 400

# %%
statss= q_learning(env, estimator, 400,discount_factor=1)
# Out:
# Step 140 @ Episode 400/400 (-155.0)

# %%
plot_episode_stats(statss, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test4=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 137,	score: -137.0
# Episode: 1,	Steps: 137,	score: -137.0
# Episode: 2,	Steps: 136,	score: -136.0
# Episode: 3,	Steps: 178,	score: -178.0
# Episode: 4,	Steps: 133,	score: -133.0
# Episode: 5,	Steps: 113,	score: -113.0
# Episode: 6,	Steps: 135,	score: -135.0
# Episode: 7,	Steps: 114,	score: -114.0
# Episode: 8,	Steps: 136,	score: -136.0
# Episode: 9,	Steps: 172,	score: -172.0
# Episode: 10,	Steps: 134,	score: -134.0
# Episode: 11,	Steps: 179,	score: -179.0
# Episode: 12,	Steps: 108,	score: -108.0
# Episode: 13,	Steps: 136,	score: -136.0
# Episode: 14,	Steps: 138,	score: -138.0
# Episode: 15,	Steps: 136,	score: -136.0
# Episode: 16,	Steps: 172,	score: -172.0
# Episode: 17,	Steps: 136,	score: -136.0
# Episode: 18,	Steps: 123,	score: -123.0
# Episode: 19,	Steps: 137,	score: -137.0

# %%
plot_episode_stats(stats_test4, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# 200

# %%
statstt= q_learning(env, estimator, 200,discount_factor=1)
# Out:
# Step 138 @ Episode 200/200 (-143.0)

# %%
plot_episode_stats(statstt, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test5=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 99,	score: -99.0
# Episode: 1,	Steps: 140,	score: -140.0
# Episode: 2,	Steps: 137,	score: -137.0
# Episode: 3,	Steps: 115,	score: -115.0
# Episode: 4,	Steps: 137,	score: -137.0
# Episode: 5,	Steps: 181,	score: -181.0
# Episode: 6,	Steps: 145,	score: -145.0
# Episode: 7,	Steps: 137,	score: -137.0
# Episode: 8,	Steps: 166,	score: -166.0
# Episode: 9,	Steps: 117,	score: -117.0
# Episode: 10,	Steps: 146,	score: -146.0
# Episode: 11,	Steps: 137,	score: -137.0
# Episode: 12,	Steps: 116,	score: -116.0
# Episode: 13,	Steps: 100,	score: -100.0
# Episode: 14,	Steps: 142,	score: -142.0
# Episode: 15,	Steps: 141,	score: -141.0
# Episode: 16,	Steps: 138,	score: -138.0
# Episode: 17,	Steps: 143,	score: -143.0
# Episode: 18,	Steps: 116,	score: -116.0
# Episode: 19,	Steps: 91,	score: -91.0

# %%
plot_episode_stats(stats_test5, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# 100

# %%
statsr= q_learning(env, estimator, 100,discount_factor=1)
# Out:
# Step 156 @ Episode 100/100 (-141.0)

# %%
plot_episode_stats(statsr, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test6=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 162,	score: -162.0
# Episode: 1,	Steps: 137,	score: -137.0
# Episode: 2,	Steps: 139,	score: -139.0
# Episode: 3,	Steps: 156,	score: -156.0
# Episode: 4,	Steps: 137,	score: -137.0
# Episode: 5,	Steps: 112,	score: -112.0
# Episode: 6,	Steps: 137,	score: -137.0
# Episode: 7,	Steps: 115,	score: -115.0
# Episode: 8,	Steps: 139,	score: -139.0
# Episode: 9,	Steps: 146,	score: -146.0
# Episode: 10,	Steps: 139,	score: -139.0
# Episode: 11,	Steps: 164,	score: -164.0
# Episode: 12,	Steps: 139,	score: -139.0
# Episode: 13,	Steps: 161,	score: -161.0
# Episode: 14,	Steps: 152,	score: -152.0
# Episode: 15,	Steps: 160,	score: -160.0
# Episode: 16,	Steps: 139,	score: -139.0
# Episode: 17,	Steps: 88,	score: -88.0
# Episode: 18,	Steps: 145,	score: -145.0
# Episode: 19,	Steps: 136,	score: -136.0

# %%
plot_episode_stats(stats_test6, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# ##when discount_factor =1 numberof epsiodes=400 .epsilon has different values in each time=[1,.1,.001]

# %% [markdown]
# 1

# %%
statsqt= q_learning(env, estimator, 400,discount_factor=1.0,epsilon=1)
# Out:
# Step 199 @ Episode 400/400 (-200.0)

# %%
plot_episode_stats(statsqt, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test7=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 200,	score: -200.0
# Episode: 1,	Steps: 162,	score: -162.0
# Episode: 2,	Steps: 200,	score: -200.0
# Episode: 3,	Steps: 200,	score: -200.0
# Episode: 4,	Steps: 200,	score: -200.0
# Episode: 5,	Steps: 200,	score: -200.0
# Episode: 6,	Steps: 200,	score: -200.0
# Episode: 7,	Steps: 200,	score: -200.0
# Episode: 8,	Steps: 200,	score: -200.0
# Episode: 9,	Steps: 200,	score: -200.0
# Episode: 10,	Steps: 200,	score: -200.0
# Episode: 11,	Steps: 200,	score: -200.0
# Episode: 12,	Steps: 200,	score: -200.0
# Episode: 13,	Steps: 200,	score: -200.0
# Episode: 14,	Steps: 200,	score: -200.0
# Episode: 15,	Steps: 200,	score: -200.0
# Episode: 16,	Steps: 200,	score: -200.0
# Episode: 17,	Steps: 200,	score: -200.0
# Episode: 18,	Steps: 200,	score: -200.0
# Episode: 19,	Steps: 200,	score: -200.0

# %%
plot_episode_stats(stats_test7, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# .1

# %%
statsz= q_learning(env, estimator, 400,discount_factor=1.0,epsilon=.1)
# Out:
# Step 150 @ Episode 400/400 (-119.0)

# %%
plot_episode_stats(statsz, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test8=test1(20,estimator)
# Out:
# Episode: 0,	Steps: 169,	score: -169.0
# Episode: 1,	Steps: 132,	score: -132.0
# Episode: 2,	Steps: 131,	score: -131.0
# Episode: 3,	Steps: 137,	score: -137.0
# Episode: 4,	Steps: 140,	score: -140.0
# Episode: 5,	Steps: 175,	score: -175.0
# Episode: 6,	Steps: 136,	score: -136.0
# Episode: 7,	Steps: 176,	score: -176.0
# Episode: 8,	Steps: 136,	score: -136.0
# Episode: 9,	Steps: 173,	score: -173.0
# Episode: 10,	Steps: 138,	score: -138.0
# Episode: 11,	Steps: 175,	score: -175.0
# Episode: 12,	Steps: 173,	score: -173.0
# Episode: 13,	Steps: 134,	score: -134.0
# Episode: 14,	Steps: 171,	score: -171.0
# Episode: 15,	Steps: 137,	score: -137.0
# Episode: 16,	Steps: 133,	score: -133.0
# Episode: 17,	Steps: 137,	score: -137.0
# Episode: 18,	Steps: 133,	score: -133.0
# Episode: 19,	Steps: 134,	score: -134.0

# %%
plot_episode_stats(stats_test8, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %% [markdown]
# .001

# %%
statsy= q_learning(env, estimator, 400,discount_factor=1.0,epsilon=.001)
# Out:
# Step 181 @ Episode 400/400 (-149.0)

# %%
plot_episode_stats(statsy, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
stats_test9=test2_display(20,estimator)
# Out:
# Episode: 0,	Steps: 199,	score: -199.0
# Episode: 1,	Steps: 343,	score: -144.0
# Episode: 2,	Steps: 486,	score: -143.0
# Episode: 3,	Steps: 669,	score: -183.0
# Episode: 4,	Steps: 864,	score: -195.0
# Episode: 5,	Steps: 1007,	score: -143.0
# Episode: 6,	Steps: 1202,	score: -195.0
# Episode: 7,	Steps: 1349,	score: -147.0
# Episode: 8,	Steps: 1549,	score: -200.0
# Episode: 9,	Steps: 1693,	score: -144.0
# Episode: 10,	Steps: 1893,	score: -200.0
# Episode: 11,	Steps: 2050,	score: -157.0
# Episode: 12,	Steps: 2250,	score: -200.0
# Episode: 13,	Steps: 2450,	score: -200.0
# Episode: 14,	Steps: 2594,	score: -144.0
# Episode: 15,	Steps: 2736,	score: -142.0
# Episode: 16,	Steps: 2931,	score: -195.0
# Episode: 17,	Steps: 3126,	score: -195.0
# Episode: 18,	Steps: 3273,	score: -147.0
# Episode: 19,	Steps: 3472,	score: -199.0

# %%
plot_episode_stats(stats_test9, smoothing_window=5)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)
